# %%
# Importar librerías
import pandas as pd

# %%
# Lista de diccionarios
data = [
    {"price": "$100", "neighbourhood": "Palermo"},
    {"price": "$120", "neighbourhood": "Palermo"}
]

# %%
# Convertimos data a DataFrame
df = pd.DataFrame(data)
df.shape
# Out:
# (2, 2)

# %%
int(["2"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int(["2"])
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
tupla = df.shape
tupla[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 tupla = df.shape
# ----> 2 tupla[3]
#
# IndexError: tuple index out of range

# %%
df.describe(include="number")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.describe(include="number")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:11995, in NDFrame.describe(self, percentiles, include, exclude)
#   11753 @final
#   11754 def describe(
#   11755     self,
#    (...)  11758     exclude=None,
#   11759 ) -> Self:
#   11760     """
#   11761     Generate descriptive statistics.
#   11762
#    (...)  11993     max            NaN      3.0
#   11994     """
# > 11995     return describe_ndframe(
#   11996         obj=self,
#   11997         include=include,
#   11998         exclude=exclude,
#   11999         percentiles=percentiles,
#   12000     ).__finalize__(self, method="describe")
#
# ...

# %%
# manejo de exceptions
try:
    df.describe(include="number")
except ValueError:
    print("No hay datos int")
except Exception as error:
    print(f"ERROR: {error}")
# Out:
# No hay datos int
